# %% [markdown]
# <a href="https://colab.research.google.com/github/Naveen-90/dl/blob/main/Untitled27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,GRU,Dense
from tensorflow.keras.preprocessing import sequence

# %%
max_words = 5000
(xt,yt),(xte,yte)= imdb.load_data(num_words=max_words)

max_len =500
xt=sequence.pad_sequences(xt,maxlen=max_len)
xte=sequence.pad_sequences(xte,maxlen=max_len)

model=Sequential()
model.add(Embedding(max_words,100,input_length=max_len))
model.add(GRU(128))
model.add(Dense(1,activation='sigmoid'))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 2s 0us/step

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
batch_size=128
epochs=5
model.fit(xt,yt,batch_size=batch_size,epochs=epochs)
# Out:
# Epoch 1/5
# 196/196 [==============================] - 58s 250ms/step - loss: 0.5990 - accuracy: 0.6636
# Epoch 2/5
# 196/196 [==============================] - 26s 135ms/step - loss: 0.3430 - accuracy: 0.8516
# Epoch 3/5
# 196/196 [==============================] - 19s 99ms/step - loss: 0.2683 - accuracy: 0.8925
# Epoch 4/5
# 196/196 [==============================] - 16s 80ms/step - loss: 0.2092 - accuracy: 0.9213
# Epoch 5/5
# 196/196 [==============================] - 14s 71ms/step - loss: 0.1727 - accuracy: 0.9363

# %%
loss,accuracy=model.evaluate(xte,yte,batch_size=batch_size)
print("accuracy:",accuracy)
print("loss:",loss)
# Out:
# 196/196 [==============================] - 3s 12ms/step - loss: 0.3350 - accuracy: 0.8754
# accuracy: 0.8754000067710876
# loss: 0.33500421047210693

# %%
history=model.fit(xt,yt,batch_size=batch_size,epochs=epochs)
# Out:
# Epoch 1/5
# 196/196 [==============================] - 9s 45ms/step - loss: 0.1411 - accuracy: 0.9484
# Epoch 2/5
# 196/196 [==============================] - 10s 50ms/step - loss: 0.1235 - accuracy: 0.9549
# Epoch 3/5
# 196/196 [==============================] - 9s 45ms/step - loss: 0.1005 - accuracy: 0.9658
# Epoch 4/5
# 196/196 [==============================] - 10s 49ms/step - loss: 0.0815 - accuracy: 0.9736
# Epoch 5/5
# 196/196 [==============================] - 8s 40ms/step - loss: 0.0650 - accuracy: 0.9793

# %%
train_loss1 = history.history['loss']
train_acc1 = history.history['accuracy']
xc1=range(len(train_acc1))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc1, train_acc1)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend('train')

# %%
from tensorflow.keras.layers import Embedding,LSTM,Dense

# %%
model = Sequential()
model.add(Embedding(max_words,100, input_length=max_len))
model.add(LSTM(128))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
epochs = 5
batch_size = 128

hist=model.fit(xt, yt, epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/5
# 196/196 [==============================] - 39s 187ms/step - loss: 0.5269 - accuracy: 0.7308
# Epoch 2/5
# 196/196 [==============================] - 24s 124ms/step - loss: 0.2859 - accuracy: 0.8863
# Epoch 3/5
# 196/196 [==============================] - 14s 69ms/step - loss: 0.2422 - accuracy: 0.9058
# Epoch 4/5
# 196/196 [==============================] - 13s 65ms/step - loss: 0.2083 - accuracy: 0.9197
# Epoch 5/5
# 196/196 [==============================] - 13s 66ms/step - loss: 0.1807 - accuracy: 0.9330

# %%
loss,accuracy=model.evaluate(xte,yte,batch_size=batch_size)
print("accuracy:",accuracy)
print("loss:",loss)
# Out:
# 196/196 [==============================] - 4s 15ms/step - loss: 0.3435 - accuracy: 0.8713
# accuracy: 0.8713200092315674
# loss: 0.3434629738330841

# %%
train_loss2 = hist.history['loss']
train_acc2 = hist.history['accuracy']
xc2=range(len(train_acc2))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc2, train_acc2)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend('train')

# %%
from tensorflow.keras.layers import Embedding,RNN
from keras import layers

# %%
model = Sequential()
model.add(Embedding(max_words,100, input_length=max_len))
model.add(layers.LSTM(128))
model.add(layers.Dense(10))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
epochs = 5
batch_size = 128

h=model.fit(xt, yt, epochs=epochs, batch_size=batch_size, validation_split=0.2)
# Out:
# Epoch 1/5
# 157/157 [==============================] - 33s 194ms/step - loss: 0.4888 - accuracy: 0.7538 - val_loss: 0.3708 - val_accuracy: 0.8384
# Epoch 2/5
# 157/157 [==============================] - 22s 143ms/step - loss: 0.2865 - accuracy: 0.8867 - val_loss: 0.3515 - val_accuracy: 0.8700
# Epoch 3/5
# 157/157 [==============================] - 15s 98ms/step - loss: 0.2131 - accuracy: 0.9158 - val_loss: 0.3521 - val_accuracy: 0.8726
# Epoch 4/5
# 157/157 [==============================] - 14s 91ms/step - loss: 0.1846 - accuracy: 0.9309 - val_loss: 0.4040 - val_accuracy: 0.8546
# Epoch 5/5
# 157/157 [==============================] - 11s 68ms/step - loss: 0.1438 - accuracy: 0.9474 - val_loss: 0.4125 - val_accuracy: 0.8466

# %%
loss,accuracy=model.evaluate(xte,yte,batch_size=batch_size)
print("accuracy:",accuracy)
print("loss:",loss)
# Out:
# 196/196 [==============================] - 3s 15ms/step - loss: 0.4102 - accuracy: 0.8544
# accuracy: 0.8543599843978882
# loss: 0.41024428606033325

# %%
train_loss3 = h.history['loss']
train_acc3 = h.history['accuracy']
xc3=range(len(train_loss3))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc3, train_acc3)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend('train')

# %%
plt.plot(xc1, train_acc1)
plt.plot(xc2, train_acc2)
plt.plot(xc3, train_acc3)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["GRU","LSTM","RNN"])
